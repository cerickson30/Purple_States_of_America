# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import geopandas as gpd

# %%
states_df = pd.read_csv('../data/states_list.txt')

# %%
url = 'https://en.wikipedia.org/wiki/2016_United_States_presidential_election_in_' +  '_'.join(states_df.iloc[0])

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
tables = soup.find_all('table')

# %%
tables[7]
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <tbody><tr>
# <th colspan="1">
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Donald_Trump" title="Donald Trump">Donald Trump</a>
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Hillary_Clinton" title="Hillary Clinton">Hillary Clinton</a>
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Gary_Johnson" title="Gary Johnson">Gary Johnson</a>
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Jill_Stein" title="Jill Stein">Jill Stein</a>
# </th>
# <th colspan="2" style="text-align:center;">Write-ins
# </th>
# <th style="text-align:center;">Total votes
# </th></tr>
# <tr>
# <th align="center">County
# </th>
# <th data-sort-type="number" style="text-align:center;">Votes
# </th>
# <th data-sort-type="number" style="text-align:center;">%
# </th>
# <th data-sort-type="number" style="text-align:center;">Votes
# </th>
# ...

# %%
counties_table = soup.find('table', {'class':'wikitable sortable'})
counties_table
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <tbody><tr>
# <th colspan="1">
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Donald_Trump" title="Donald Trump">Donald Trump</a>
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Hillary_Clinton" title="Hillary Clinton">Hillary Clinton</a>
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Gary_Johnson" title="Gary Johnson">Gary Johnson</a>
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Jill_Stein" title="Jill Stein">Jill Stein</a>
# </th>
# <th colspan="2" style="text-align:center;">Write-ins
# </th>
# <th style="text-align:center;">Total votes
# </th></tr>
# <tr>
# <th align="center">County
# </th>
# <th data-sort-type="number" style="text-align:center;">Votes
# </th>
# <th data-sort-type="number" style="text-align:center;">%
# </th>
# <th data-sort-type="number" style="text-align:center;">Votes
# </th>
# ...

# %%
indices = []
column_counter = 0
for th in counties_table.find_all('th'):
    print(th)
    if th.a is not None and 'Donald Trump' in th.a.title:
        print(th)
# Out:
# <th colspan="1">
# </th>
# <th colspan="2" style="text-align:center;"><a href="/wiki/Donald_Trump" title="Donald Trump">Donald Trump</a>
# </th>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/craigmac/GitHub/Purple_States_of_America/code/scraping_2016.ipynb Cell 7' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/craigmac/GitHub/Purple_States_of_America/code/scraping_2016.ipynb#ch0000015?line=2'>3</a> for th in counties_table.find_all('th'):
#       <a href='vscode-notebook-cell:/Users/craigmac/GitHub/Purple_States_of_America/code/scraping_2016.ipynb#ch0000015?line=3'>4</a>     print(th)
# ----> <a href='vscode-notebook-cell:/Users/craigmac/GitHub/Purple_States_of_America/code/scraping_2016.ipynb#ch0000015?line=4'>5</a>     if th.a is not None and 'Donald Trump' in th.a.title:
# ...
